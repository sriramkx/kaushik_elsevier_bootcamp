# %%
import requests

from bs4 import BeautifulSoup

r = requests.get("https://www.ticketnew.com/online-advance-booking/Movies/C/Chennai")
c = r.content
c
# Out:
# b'<!DOCTYPE html><html lang="en"><head><meta name="next-head-count" content="9"/><script>let _N_E;</script><script async="" src="https://pwebassets.paytm.com/firefly-modules/es-module-shims/index.js"></script><script type="importmap">{"imports":{"react":"https://pwebassets.paytm.com/firefly-modules/react/18.2.0/index.js","react-dom":"https://pwebassets.paytm.com/firefly-modules/react-dom/18.2.0/index.js","storefront-h5-sdk":"https://pwebassets.paytm.com/firefly-modules/storefront-h5-sdk/3.19.3/index.js"}}</script><meta http-equiv="Content-Type" content="text/html; charset=utf-8"/><meta http-equiv="Cache-Control" content="no-cache, no-store, must-revalidate"/><meta name="p:domain_verify" content="578fa68d1988f66b6eeb98681b6646ae"/><meta name="viewport" content="width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=1,user-scalable=no,viewport-fit=cover"/><link rel="preconnect" href="https://pwebassets.paytm.com"/><link rel="dns-prefetch" href="https://pwebassets.paytm.com"/>
# ...

# %%
soup=BeautifulSoup(c,"html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Transitional//EN" "https://www.w3.org/TR/xhtml1/DTD/xhtml1-transitional.dtd">
# <html lang="en" xml:lang="en" xmlns="https://www.w3.org/1999/xhtml">
#  <head id="Head1">
#   <title>
#    Chennai - Movie ticket online booking &amp; show times near you.
#   </title>
#   <link href="//cdn11.ticketnew.com/css/main.css" rel="stylesheet" type="text/css"/>
#   <link href="//cdnjs.cloudflare.com/ajax/libs/slick-carousel/1.8.1/slick.min.css" rel="stylesheet" type="text/css"/>
#   <style type="text/css">
#    .slick-slide img {
#             width: 100%;
#             max-height: 400px;
#         }
#
#         .slick-prev,
#         .slick-next {
#             position: absolute;
#             display: block;
#             height: 80px;
#             width: 48px;
#             line-height: 0px;
#             font-size: 0px;
#             cursor: pointer;
#             color: transparent;
#             top: 50%;
# ...

# %%
all=soup.find_all("div",{"class":"tn-movie tn-section-tile"})
all
# Out:
# [<div class="tn-movie tn-section-tile" data-filter="TAMIL|2D|ADVENTURE|FANTASY|HISTORY|MYSTERY|THRILL"><a href="https://www.ticketnew.com/Aayirathil-Oruvan-Movie-Tickets-Online-Show-Timings/Online-Advance-Booking/19648/C/Chennai" onclick='GaPdetails("2738-Aayirathil Oruvan-Tamil-A-Adventure Fantasy History Mystery Thrill-now");TKTNEW.Misc.setLoader(true);'><img alt="Aayirathil Oruvan" class="poster-list" height="278px" src="https://img.ticketnew.com/tn/movie/19648/7.jpg?9821527&amp;x-oss-process=image/resize,m_mfit,w_330,h_400/quality,q_80" width="230px"/><div class="movie-details tn-section-tile-details" style="width:100% !important;padding:0px!important"><div class="title-language-and-genre"><h4 class="tn-single-line">Aayirathil Oruvan (A) - Tamil</h4><div class="tn-inline"><span class="tn-language tn-single-line" title="Tamil">TAMIL</span> <span class="border">|</span> <span class="genre">A</span></div></div><div class="book" style="background-color:#FFC20E"><h4 class="yellow" sty
# ...

# %%
len(all)
# Out:
# 36

# %%
all[0]
# Out:
# <div class="tn-movie tn-section-tile" data-filter="TAMIL|2D|ADVENTURE|FANTASY|HISTORY|MYSTERY|THRILL"><a href="https://www.ticketnew.com/Aayirathil-Oruvan-Movie-Tickets-Online-Show-Timings/Online-Advance-Booking/19648/C/Chennai" onclick='GaPdetails("2738-Aayirathil Oruvan-Tamil-A-Adventure Fantasy History Mystery Thrill-now");TKTNEW.Misc.setLoader(true);'><img alt="Aayirathil Oruvan" class="poster-list" height="278px" src="https://img.ticketnew.com/tn/movie/19648/7.jpg?9821527&amp;x-oss-process=image/resize,m_mfit,w_330,h_400/quality,q_80" width="230px"/><div class="movie-details tn-section-tile-details" style="width:100% !important;padding:0px!important"><div class="title-language-and-genre"><h4 class="tn-single-line">Aayirathil Oruvan (A) - Tamil</h4><div class="tn-inline"><span class="tn-language tn-single-line" title="Tamil">TAMIL</span> <span class="border">|</span> <span class="genre">A</span></div></div><div class="book" style="background-color:#FFC20E"><h4 class="yellow" styl
# ...

# %%
all[0].find_all("h4") #price is defined by using tag and dimension array value
# Out:
# [<h4 class="tn-single-line">Aayirathil Oruvan (A) - Tamil</h4>,
#  <h4 class="yellow" style="color:#FFFFFF !important;">Book</h4>]

# %%
all[0].find_all("h4")[0].text # to get only text
# Out:
# 'Aayirathil Oruvan (A) - Tamil'

# %%
for item in all:   #to display all price value in the website
    print(item.find_all("h4")[0].text)
# Out:
# Aayirathil Oruvan (A) - Tamil
# The Great Father - Tamil
# Wonder Woman 1984 -Tamil
# Pudhu Pettai (U/A) - Tamil
# Wonder Woman 1984 -English
# Pei Irukka Bayamen - Tamil
# Krack - Telugu
#  Solo Brathuke So Better ( u ) - Telugu
# Simtaangaran - Tamil
# Vanguard ( U/A ) - Tamil
# Tenet (U/A) - Tamil
# Aadhika vargam - Tamil
# Pattas (U) - Tamil
# Ram Prasad Ki Tehrvi - Hindi
# Tenet - English
# Vietnam Veedu - Tamil
# Rajasingam (U/A) - Tamil
# Kavalthurai Ungal Nanban (U/A) - Tamil
# Chiyangal - Tamil
# Vanguard ( U/A ) - English
# Time Up - Tamil
# Biskoth (U) - Tamil
# Kannirasi (U) - Tamil
# Kombu (U/A)-(Tamil)
# Operation JuJuPi
# Master
# Eeswaran
# Dhruva Natchathiram
# 12 O'clock
# chandni i love you
# Master
# Operation JuJuPi
# Chithakkotudu 2
# Valasa
# Krack - Telugu
#  Master

# %%
all[0].find_all("h4",{"class":"tn-single-line"}) #price it is defined by using class name
# Out:
# [<h4 class="tn-single-line">Aayirathil Oruvan (A) - Tamil</h4>]

# %%
all[0].find("h4",{"class":"tn-single-line"})
# Out:
# <h4 class="tn-single-line">Aayirathil Oruvan (A) - Tamil</h4>

# %%
all[0].find("h4",{"class":"tn-single-line"}).text
# Out:
# 'Aayirathil Oruvan (A) - Tamil'

# %%
type(all[0].find("h4",{"class":"tn-single-line"}).text)
# Out:
# str

# %%
for item in all:   #to display all price value in the website
    print(item.find_all("h4")[0].text)
    #print(item.find_all("div",{"class":"tn-inline"})[0].text)
    print(item.find_all("span",{"class":"tn-language tn-single-line"})[0].text)
    print(item.find_all("span",{"class":"genre"})[0].text)
    print("\n")
# Out:
# Aayirathil Oruvan (A) - Tamil
# TAMIL
# A
#
#
# The Great Father - Tamil
# TAMIL
# U/A
#
#
# Wonder Woman 1984 -Tamil
# TAMIL
# U/A
#
#
# Pudhu Pettai (U/A) - Tamil
# TAMIL
# U/A
#
#
# Wonder Woman 1984 -English
# ENGLISH
# U/A
#
#
# Pei Irukka Bayamen - Tamil
# TAMIL
# TBA
#
#
# Krack - Telugu
# TELUGU
# U/A
#
#
#  Solo Brathuke So Better ( u ) - Telugu
# TELUGU
# U
#
#
# Simtaangaran - Tamil
# TAMIL
# U/A
#
#
# Vanguard ( U/A ) - Tamil
# TAMIL
# U/A
#
#
# Tenet (U/A) - Tamil
# TAMIL
# U/A
#
#
# Aadhika vargam - Tamil
# TAMIL
# TBA
#
#
# Pattas (U) - Tamil
# TAMIL
# U
#
#
# Ram Prasad Ki Tehrvi - Hindi
# HINDI
# U
#
#
# Tenet - English
# ENGLISH
# U/A
#
#
# Vietnam Veedu - Tamil
# TAMIL
# U
#
#
# Rajasingam (U/A) - Tamil
# TAMIL
# U/A
#
#
# Kavalthurai Ungal Nanban (U/A) - Tamil
# TAMIL
# U/A
#
#
# Chiyangal - Tamil
# TAMIL
# U
#
#
# Vanguard ( U/A ) - English
# ENGLISH
# U/A
#
#
# Time Up - Tamil
# TAMIL
# U
#
#
# Biskoth (U) - Tamil
# TAMIL
# U
#
#
# Kannirasi (U) - Tamil
# TAMIL
# ...

# %%
l=[]
for item in all:   #to display all price value in the website
    d={}
    d["movie_name"]=item.find_all("h4")[0].text
    #print(item.find_all("div",{"class":"tn-inline"})[0].text)
    d["movie_language"]=item.find_all("span",{"class":"tn-language tn-single-line"})[0].text
    d["movie_genre"]=item.find_all("span",{"class":"genre"})[0].text
    l.append(d)

# %%
l
# Out:
# [{'movie_name': 'Aayirathil Oruvan (A) - Tamil',
#   'movie_language': 'TAMIL',
#   'movie_genre': 'A'},
#  {'movie_name': 'The Great Father - Tamil',
#   'movie_language': 'TAMIL',
#   'movie_genre': 'U/A'},
#  {'movie_name': 'Wonder Woman 1984 -Tamil ',
#   'movie_language': 'TAMIL',
#   'movie_genre': 'U/A'},
#  {'movie_name': 'Pudhu Pettai (U/A) - Tamil',
#   'movie_language': 'TAMIL',
#   'movie_genre': 'U/A'},
#  {'movie_name': 'Wonder Woman 1984 -English',
#   'movie_language': 'ENGLISH',
#   'movie_genre': 'U/A'},
#  {'movie_name': 'Pei Irukka Bayamen - Tamil',
#   'movie_language': 'TAMIL',
#   'movie_genre': 'TBA'},
#  {'movie_name': 'Krack - Telugu',
#   'movie_language': 'TELUGU',
#   'movie_genre': 'U/A'},
#  {'movie_name': ' Solo Brathuke So Better ( u ) - Telugu',
#   'movie_language': 'TELUGU',
#   'movie_genre': 'U'},
#  {'movie_name': 'Simtaangaran - Tamil ',
#   'movie_language': 'TAMIL',
#   'movie_genre': 'U/A'},
#  {'movie_name': 'Vanguard ( U/A ) - Tamil',
# ...

# %%
len(l)
# Out:
# 36

# %%
import pandas
df=pandas.DataFrame(l)

# %%
df
# Out:
#                                  movie_name movie_language movie_genre
# 0             Aayirathil Oruvan (A) - Tamil          TAMIL           A
# 1                  The Great Father - Tamil          TAMIL         U/A
# 2                 Wonder Woman 1984 -Tamil           TAMIL         U/A
# 3                Pudhu Pettai (U/A) - Tamil          TAMIL         U/A
# 4                Wonder Woman 1984 -English        ENGLISH         U/A
# 5                Pei Irukka Bayamen - Tamil          TAMIL         TBA
# 6                            Krack - Telugu         TELUGU         U/A
# 7    Solo Brathuke So Better ( u ) - Telugu         TELUGU           U
# 8                     Simtaangaran - Tamil           TAMIL         U/A
# 9                  Vanguard ( U/A ) - Tamil          TAMIL         U/A
# 10                      Tenet (U/A) - Tamil          TAMIL         U/A
# 11                   Aadhika vargam - Tamil          TAMIL         TBA
# ...

# %%
df.to_csv("newlistmovies.csv")
