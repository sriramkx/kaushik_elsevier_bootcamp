# %%
modules and packages

1. user defined modules
2, third party modules
3, core modules


pip

# %%
import pandas as pd
df=pd.read_csv('titanicnew.csv')
df.to_string()
# Out:
# '     survived  pclass                                                                                name     sex    age      fare  sibsp  parch\n0           0       3                                                             Braund, Mr. Owen Harris    male  22.00    7.2500      1      0\n1           1       1                                 Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.00   71.2833      1      0\n2           1       3                                                              Heikkinen, Miss. Laina  female  26.00    7.9250      0      0\n3           1       1                                        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.00   53.1000      1      0\n4           0       3                                                            Allen, Mr. William Henry    male  35.00    8.0500      0      0\n5           0       1                                                             McCarthy, Mr. Timothy J    male  54.00 
# ...

# %%
# !pip install selenium
# Out:
# ...
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.1/9.4 MB 4.5 MB/s eta 0:00:03
#     --------------------------------------- 0.2/9.4 MB 3.4 MB/s eta 0:00:03
#    - -------------------------------------- 0.4/9.4 MB 2.8 MB/s eta 0:00:04
#    -- ------------------------------------- 0.7/9.4 MB 3.8 MB/s eta 0:00:03
#    --- ------------------------------------ 0.9/9.4 MB 4.2 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.1/9.4 MB 4.4 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.2/9.4 MB 3.9 MB/s eta 0:00:03
#    ------ --------------------------------- 1.5/9.4 MB 4.1 MB/s eta 0:00:02
#    ------- -------------------------------- 1.7/9.4 MB 4.2 MB/s eta 0:00:02
#    ------- -------------------------------- 1.8/9.4 MB 4.0 MB/s eta 0:00:02
#    -------- ------------------------------- 1.9/9.4 MB 3.9 MB/s eta 0:00:02
# ...

# %%
import math as m

a=34.5657
m.ceil(a)
# Out:
# 35

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
GUI - tkinter

# %%
from tkinter import *
root =Tk()
root.title('welcome elseveir')
root.geometry('500x500')
mylabel=Label(root,text="hello elseveir",font=('Arial Bold',50))


mylabel.pack()

mybutton = Button(root,text="Log in ",fg="white",bg="green")

mybutton.pack()
root.mainloop()

# %%
regular expression

# %%
s="hello welcome to the class and he is a good boy"
s1=s.replace('h','z')
s1
